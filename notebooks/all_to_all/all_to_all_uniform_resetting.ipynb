# %%
import numpy as np
import matplotlib.pyplot as plt
from numba import njit, prange

# %% [markdown]
# # Uniform Resetting

# %%
@njit
def voter_model_uniform(N, t, r, m0):
    '''Takes:
    N: number of agents
    t: time in MC steps
    r: resetting rate per MC step
    m0: starting magnetisation
    
        Returns:
    config: The config at time t
    res: number of resets'''
    
    # Initialize
    n = int(N*(m0+1)/2)  
    time = 0.0

    while time < t:
        la = r + 2* ( n*(N-n)/(N-1) )
        dt = -np.log(np.random.random()) / la
        
        # Check if this step exceeds our simulation duration
        if time + dt > t:
            # We spend the remainder of the time in the current state 'n'
            break
            
        time += dt

        if np.random.random() < r/la:
            n = np.random.randint(0,N+1)
        else:
            if np.random.random() < 0.5:
                n += 1
            else:
                n += -1
    
    return(2*n/N-1)

# %%
@njit(parallel=True)
def dist_uniform(N, t, r, m0, samples):
    '''Returns the magnetisation at time t for some samples'''
    res = np.zeros(samples)

    for i in prange(samples):
        res[i] = voter_model_uniform(N, t, r, m0)
    
    return res

# %% [markdown]
# ### Compare

# %%
r = 0.1
N = 500
bins = 35
d = dist_uniform(N, 200, r, 0, 100000)

# %%
plt.title("Stationary Solution: Theory vs Simulation")
plt.xlabel("m")
plt.ylabel("PDF")

plt.hist(d, bins = bins, density = True, label = "Simulation", alpha = 0.8)
plt.hlines(y=0.5*r/(2/N+r), xmin=-1, xmax=1, color="r", lw=3, label="Theory")
plt.scatter([-1+1/bins,1-1/bins], [0.5*r/(2/N+r)+0.5*(1-r/(2/N+r))/(2/bins), 0.5*r/(2/N+r)+0.5*(1-r/(2/N+r))/(2/bins)], color = "r")

plt.legend()
plt.savefig("../figures/all_to_all/theo_sim_uni.pdf")
